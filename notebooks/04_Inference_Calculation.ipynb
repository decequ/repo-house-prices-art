# %%
import pandas as pd
import numpy as np
import joblib

import logging
import time

# %%
inference_data = pd.read_csv('../data/raw/test.csv')
inference_data.drop(['Id'], axis=1,inplace=True)
inference_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RH         80.0    11622   Pave   NaN      Reg
# 1          20       RL         81.0    14267   Pave   NaN      IR1
# 2          60       RL         74.0    13830   Pave   NaN      IR1
# 3          60       RL         78.0     9978   Pave   NaN      IR1
# 4         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 2         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 3         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 4         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
house_prices_pipeline = joblib.load('../models/house_prices_pipeline.pkl')
house_prices_pipeline
# Out:
# Pipeline(steps=[('drop_features',
#                  DropFeatures(features_to_drop=['GarageType', 'Street',
#                                                 'Condition1', 'Condition2',
#                                                 'Fence', 'Utilities',
#                                                 'GarageCond', 'Fireplaces',
#                                                 'BsmtCond', 'BsmtFinSF1',
#                                                 'FullBath', 'BsmtFinSF2',
#                                                 'BsmtUnfSF', 'MoSold',
#                                                 'Electrical', 'Exterior2nd',
#                                                 'PoolQC', 'Heating',
#                                                 'KitchenAbvGr', 'HouseStyle',
#                                                 'GarageYrBlt', '2ndFlrSF',
#                                                 'MasVnrType', 'ExterCond'...
# ...

# %%
predicciones = house_prices_pipeline.predict(inference_data)
# Out:
# c:\Users\DC\anaconda3\envs\venv_papd_a\lib\site-packages\feature_engine\encoding\base_encoder.py:260: UserWarning: During the encoding, NaN values were introduced in the feature(s) Neighborhood, Exterior1st.
#   warnings.warn(

# %%
predicciones
# Out:
# array([119197.865, 153596.   , 182213.315, ..., 139086.36 , 109741.8  ,
#        230632.79 ], shape=(1459,))
